# %%
#Description: 

import os
import cv2
import math
import numpy as np 
from numpy import savetxt, genfromtxt

import silhouette_extract
import projection


#Setting the path
data_dir = os.path.expanduser('~')
data_dir = data_dir + "/Downloads/DataSets/beethoven_data/images/"

#Dimensions of the initial canvas of voxels           
step_size = 2 #0.42
xmin = -8
xmax = 5
ymin = -8
ymax = 8
zmin = -5
zmax = 16 #17.5


total_voxels=int((xmax-xmin)/step_size)*int((ymax-ymin)/step_size)*int((zmax-zmin)/step_size)

#Image dimensions
height = 768
width = 1024

#Initial canvas of voxels defined as a three dimentional array of true booleans
obj = np.ones((int((xmax-xmin)/step_size), int((ymax-ymin)/step_size), int((zmax-zmin)/step_size)), dtype = bool)


out_cnt = 0
carve_cnt = 0
image_pixel_mark_situ = {}
for file in os.listdir(data_dir):
    #Initializing the pixel marking matrix to account for voxels occlusion from some camera views
    pixel_map = np.zeros((height, width), dtype = np.int8)
    image_pixel_mark_situ[file] = pixel_map
#Method to check the voxel consistency using only the background constraint
def background_consistency_check(i, j, k):
    global out_cnt, image_pixel_mark_situ
    consist = True
    voxel_cord = np.array([[xmin + i*step_size], [ymin + j*step_size],[zmin + k*step_size], [1]])

    for file in os.listdir(data_dir):
        #Reading each image's segmentation and projection matrix    
        img_mask = silhouette_extract.get_mask(file)
        P = projection.projectionMatrix(file)
        #Projecting the voxel on the 2D image
        pix_cord = P.dot(voxel_cord)
        pix_cord = pix_cord / pix_cord[2,0] # division by the last vector's element of the
                                                        # homogeneous representation to get the pixel's coordinates in the
                                                        #extracted image

        #if the voxel is projected outside the 2D image boundaries, this means that the voxel is not in the camera's visual field
        #and the info provided by the correspondent 2D image cannot be used
        if pix_cord[1,0] >= height or pix_cord[0,0] < 0 or pix_cord[0,0] >= width or pix_cord[1,0] < 0:
            out_cnt = out_cnt+1
            continue    
        
        if image_pixel_mark_situ[file][int(pix_cord[1,0]), int(pix_cord[0,0])] == 0:
            # Pixels with intensity values 0 (black) denote object occupancy
            if img_mask[int(pix_cord[1,0]), int(pix_cord[0,0]), 0] > 0 or img_mask[int(pix_cord[1,0]), int(pix_cord[0,0]), 1] > 0 or img_mask[int(pix_cord[1,0]), int(pix_cord[0,0]), 2] > 0:
                #If the pixel is part of the background (i.e. not black or white in this case), it will be carved out
                consist = False
                break
            
    if not consist:
        return False
    else:
        
        # area block. This idea is implemented to avoid the extraction and the inclusion in the 
        # calculation of the projected pixel's color from an image where the correspondent voxel cannot be seen
        # in the first place (i.e. the correspondent voxel is hidden by another voxel that was previously proven
        # to be consistent)
        voxel_cord1 = np.array([[xmin + i*step_size+step_size], [ymin + j*step_size+step_size],[zmin + k*step_size+step_size], [1]])
        for file in os.listdir(data_dir):
            P = projection.projectionMatrix(file)
            pix_cord = P.dot(voxel_cord)
            pix_cord = pix_cord / pix_cord[2,0]
            if pix_cord[1,0] >= height or pix_cord[0,0] < 0 or pix_cord[0,0] >= width or pix_cord[1,0] < 0:
                continue 
            if image_pixel_mark_situ[file][int(pix_cord[1,0]), int(pix_cord[0,0])] == 0:
               pix_cord1 = P.dot(voxel_cord1)
               pix_cord1 = pix_cord1 / pix_cord1[2,0]
               pix_length = int(np.linalg.norm(pix_cord-pix_cord1))
        
               for m in range(int(pix_cord[1,0]-pix_length/2),int(pix_cord[1,0] + pix_length/2)):
                    for n in range(int(pix_cord[0,0]-pix_length/2),int(pix_cord[0,0] + pix_length/2)):
                        image_pixel_mark_situ[file][m,n] = 100 #any other non-zero number can be placed here
        return True        

if __name__ == "__main__":
    voxel_count = 0
    eval_list = []
    # carving out the visual hull
    for i in range(obj.shape[0]):
        for j in range(obj.shape[1]):
            for k in range(obj.shape[2]):
                voxel_count +=1
                print("processed "+ str(voxel_count/total_voxels*100) + "% of voxels")
                if not background_consistency_check(i, j, k):
                    obj[i,j,k] = 0
                    carve_cnt = carve_cnt+1  
    #Saving the output 3D shape that was carved from the initial canvas of voxels as a .txt file
    print(obj.size, obj.size-carve_cnt, out_cnt)
    final_file = open("./visual_hull_result.txt", "w")
    head_line = "{} {} {} {} {} {} {} {}\n" # step_size, xmin, xmax, ymin, ymax, zmin, zmax, is_colored version
    voxel_elem = "{} "
    final_file.write(head_line.format(step_size, xmin, xmax, ymin, ymax, zmin, zmax, 0))
            
    for i in range(obj.shape[0]):
        for j in range(obj.shape[1]):
            for k in range(obj.shape[2]):
                final_file.write(voxel_elem.format(int(obj[i,j,k])))
                eval_list.append(int(obj[i,j,k]))  

    final_file.close()
    eval_array = np.array(eval_list)
    savetxt('background_only.csv',eval_array,delimiter=',')                                   
# end of the visual hull build
# Out:
# processed 0.20833333333333334% of voxels
# processed 0.4166666666666667% of voxels
# processed 0.625% of voxels
# processed 0.8333333333333334% of voxels
# processed 1.0416666666666665% of voxels
# processed 1.25% of voxels
# processed 1.4583333333333333% of voxels
# processed 1.6666666666666667% of voxels
# processed 1.875% of voxels
# processed 2.083333333333333% of voxels
# processed 2.2916666666666665% of voxels
# processed 2.5% of voxels
# processed 2.7083333333333335% of voxels
# processed 2.9166666666666665% of voxels
# processed 3.125% of voxels
# processed 3.3333333333333335% of voxels
# processed 3.5416666666666665% of voxels
# processed 3.75% of voxels
# processed 3.958333333333333% of voxels
# processed 4.166666666666666% of voxels
# processed 4.375% of voxels
# processed 4.583333333333333% of voxels
# processed 4.791666666666667% of voxels
# processed 5.0% of voxels
# processed 5.208333333333334% of voxels
# processed 5.416666666666667% of voxels
# processed 5.625% of voxels
# processed 5.833333333333333% of voxels
# processed 6.041666666666667% of voxels
# processed 6.25% of voxels
# processed 6.458333333333334% of voxels
# processed 6.666666666666667% of voxels
# processed 6.875000000000001% of voxels
# processed 7.083333333333333% of voxels
# processed 7.291666666666667% of voxels
# processed 7.5% of voxels
# processed 7.708333333333334% of voxels
# processed 7.916666666666666% of voxels
# processed 8.125% of voxels
# processed 8.333333333333332% of voxels
# processed 8.541666666666666% of voxels
# processed 8.75% of voxels
# processed 8.958333333333334% of voxels
# processed 9.166666666666666% of voxels
# processed 9.375% of voxels
# processed 9.583333333333334% of voxels
# processed 9.791666666666666% of voxels
# processed 10.0% of voxels
# processed 10.208333333333334% of voxels
# processed 10.416666666666668% of voxels
# processed 10.625% of voxels
# processed 10.833333333333334% of voxels
# processed 11.041666666666666% of voxels
# processed 11.25% of voxels
# processed 11.458333333333332% of voxels
# processed 11.666666666666666% of voxels
# processed 11.875% of voxels
# processed 12.083333333333334% of voxels
# processed 12.291666666666666% of voxels
# processed 12.5% of voxels
# processed 12.708333333333332% of voxels
# processed 12.916666666666668% of voxels
# processed 13.125% of voxels
# processed 13.333333333333334% of voxels
# processed 13.541666666666666% of voxels
# processed 13.750000000000002% of voxels
# processed 13.958333333333334% of voxels
# processed 14.166666666666666% of voxels
# processed 14.374999999999998% of voxels
# processed 14.583333333333334% of voxels
# processed 14.791666666666666% of voxels
# processed 15.0% of voxels
# processed 15.208333333333332% of voxels
# processed 15.416666666666668% of voxels
# processed 15.625% of voxels
# processed 15.833333333333332% of voxels
# processed 16.041666666666668% of voxels
# processed 16.25% of voxels
# processed 16.458333333333332% of voxels
# processed 16.666666666666664% of voxels
# processed 16.875% of voxels
# processed 17.083333333333332% of voxels
# processed 17.291666666666668% of voxels
# processed 17.5% of voxels
# processed 17.708333333333336% of voxels
# processed 17.916666666666668% of voxels
# processed 18.125% of voxels
# processed 18.333333333333332% of voxels
# processed 18.541666666666668% of voxels
# processed 18.75% of voxels
# processed 18.958333333333332% of voxels
# processed 19.166666666666668% of voxels
# processed 19.375% of voxels
# processed 19.583333333333332% of voxels
# processed 19.791666666666664% of voxels
# processed 20.0% of voxels
# processed 20.208333333333332% of voxels
# processed 20.416666666666668% of voxels
# processed 20.625% of voxels
# processed 20.833333333333336% of voxels
# processed 21.041666666666668% of voxels
# processed 21.25% of voxels
# processed 21.458333333333332% of voxels
# processed 21.666666666666668% of voxels
# processed 21.875% of voxels
# processed 22.083333333333332% of voxels
# processed 22.291666666666668% of voxels
# processed 22.5% of voxels
# processed 22.708333333333332% of voxels
# processed 22.916666666666664% of voxels
# processed 23.125% of voxels
# processed 23.333333333333332% of voxels
# processed 23.541666666666668% of voxels
# processed 23.75% of voxels
# processed 23.958333333333336% of voxels
# processed 24.166666666666668% of voxels
# processed 24.375% of voxels
# processed 24.583333333333332% of voxels
# processed 24.791666666666668% of voxels
# processed 25.0% of voxels
# processed 25.208333333333332% of voxels
# processed 25.416666666666664% of voxels
# processed 25.624999999999996% of voxels
# processed 25.833333333333336% of voxels
# processed 26.041666666666668% of voxels
# processed 26.25% of voxels
# processed 26.458333333333332% of voxels
# processed 26.666666666666668% of voxels
# processed 26.875% of voxels
# processed 27.083333333333332% of voxels
# processed 27.291666666666664% of voxels
# processed 27.500000000000004% of voxels
# processed 27.708333333333336% of voxels
# processed 27.916666666666668% of voxels
# processed 28.125% of voxels
# processed 28.333333333333332% of voxels
# processed 28.541666666666664% of voxels
# processed 28.749999999999996% of voxels
# processed 28.958333333333336% of voxels
# processed 29.166666666666668% of voxels
# processed 29.375% of voxels
# processed 29.583333333333332% of voxels
# processed 29.791666666666668% of voxels
# processed 30.0% of voxels
# processed 30.208333333333332% of voxels
# processed 30.416666666666664% of voxels
# processed 30.625000000000004% of voxels
# processed 30.833333333333336% of voxels
# processed 31.041666666666668% of voxels
# processed 31.25% of voxels
# processed 31.458333333333332% of voxels
# processed 31.666666666666664% of voxels
# processed 31.874999999999996% of voxels
# processed 32.083333333333336% of voxels
# processed 32.29166666666667% of voxels
# processed 32.5% of voxels
# processed 32.708333333333336% of voxels
# processed 32.916666666666664% of voxels
# processed 33.125% of voxels
# processed 33.33333333333333% of voxels
# processed 33.541666666666664% of voxels
# processed 33.75% of voxels
# processed 33.958333333333336% of voxels
# processed 34.166666666666664% of voxels
# processed 34.375% of voxels
# processed 34.583333333333336% of voxels
# processed 34.791666666666664% of voxels
# processed 35.0% of voxels
# processed 35.208333333333336% of voxels
# processed 35.41666666666667% of voxels
# processed 35.625% of voxels
# processed 35.833333333333336% of voxels
# processed 36.041666666666664% of voxels
# processed 36.25% of voxels
# processed 36.45833333333333% of voxels
# processed 36.666666666666664% of voxels
# processed 36.875% of voxels
# processed 37.083333333333336% of voxels
# processed 37.291666666666664% of voxels
# processed 37.5% of voxels
# processed 37.708333333333336% of voxels
# processed 37.916666666666664% of voxels
# processed 38.125% of voxels
# processed 38.333333333333336% of voxels
# processed 38.54166666666667% of voxels
# processed 38.75% of voxels
# processed 38.958333333333336% of voxels
# processed 39.166666666666664% of voxels
# processed 39.375% of voxels
# processed 39.58333333333333% of voxels
# processed 39.791666666666664% of voxels
# processed 40.0% of voxels
# processed 40.208333333333336% of voxels
# processed 40.416666666666664% of voxels
# processed 40.625% of voxels
# processed 40.833333333333336% of voxels
# processed 41.041666666666664% of voxels
# processed 41.25% of voxels
# processed 41.458333333333336% of voxels
# processed 41.66666666666667% of voxels
# processed 41.875% of voxels
# processed 42.083333333333336% of voxels
# processed 42.291666666666664% of voxels
# processed 42.5% of voxels
# processed 42.70833333333333% of voxels
# processed 42.916666666666664% of voxels
# processed 43.125% of voxels
# processed 43.333333333333336% of voxels
# processed 43.541666666666664% of voxels
# processed 43.75% of voxels
# processed 43.958333333333336% of voxels
# processed 44.166666666666664% of voxels
# processed 44.375% of voxels
# processed 44.583333333333336% of voxels
# processed 44.79166666666667% of voxels
# processed 45.0% of voxels
# processed 45.208333333333336% of voxels
# processed 45.416666666666664% of voxels
# processed 45.625% of voxels
# processed 45.83333333333333% of voxels
# processed 46.041666666666664% of voxels
# processed 46.25% of voxels
# processed 46.458333333333336% of voxels
# processed 46.666666666666664% of voxels
# processed 46.875% of voxels
# processed 47.083333333333336% of voxels
# processed 47.291666666666664% of voxels
# processed 47.5% of voxels
# processed 47.708333333333336% of voxels
# processed 47.91666666666667% of voxels
# processed 48.125% of voxels
# processed 48.333333333333336% of voxels
# processed 48.541666666666664% of voxels
# processed 48.75% of voxels
# processed 48.95833333333333% of voxels
# processed 49.166666666666664% of voxels
# processed 49.375% of voxels
# processed 49.583333333333336% of voxels
# processed 49.791666666666664% of voxels
# processed 50.0% of voxels
# processed 50.208333333333336% of voxels
# processed 50.416666666666664% of voxels
# processed 50.625% of voxels
# processed 50.83333333333333% of voxels
# processed 51.041666666666664% of voxels
# processed 51.24999999999999% of voxels
# processed 51.45833333333333% of voxels
# processed 51.66666666666667% of voxels
# processed 51.87500000000001% of voxels
# processed 52.083333333333336% of voxels
# processed 52.29166666666667% of voxels
# processed 52.5% of voxels
# processed 52.708333333333336% of voxels
# processed 52.916666666666664% of voxels
# processed 53.125% of voxels
# processed 53.333333333333336% of voxels
# processed 53.541666666666664% of voxels
# processed 53.75% of voxels
# processed 53.95833333333333% of voxels
# processed 54.166666666666664% of voxels
# processed 54.37499999999999% of voxels
# processed 54.58333333333333% of voxels
# processed 54.79166666666667% of voxels
# processed 55.00000000000001% of voxels
# processed 55.208333333333336% of voxels
# processed 55.41666666666667% of voxels
# processed 55.625% of voxels
# processed 55.833333333333336% of voxels
# processed 56.041666666666664% of voxels
# processed 56.25% of voxels
# processed 56.458333333333336% of voxels
# processed 56.666666666666664% of voxels
# processed 56.875% of voxels
# processed 57.08333333333333% of voxels
# processed 57.291666666666664% of voxels
# processed 57.49999999999999% of voxels
# processed 57.70833333333333% of voxels
# processed 57.91666666666667% of voxels
# processed 58.12500000000001% of voxels
# processed 58.333333333333336% of voxels
# processed 58.54166666666667% of voxels
# processed 58.75% of voxels
# processed 58.958333333333336% of voxels
# processed 59.166666666666664% of voxels
# processed 59.375% of voxels
# processed 59.583333333333336% of voxels
# processed 59.791666666666664% of voxels
# processed 60.0% of voxels
# processed 60.20833333333333% of voxels
# processed 60.416666666666664% of voxels
# processed 60.62499999999999% of voxels
# processed 60.83333333333333% of voxels
# processed 61.04166666666667% of voxels
# processed 61.25000000000001% of voxels
# processed 61.458333333333336% of voxels
# processed 61.66666666666667% of voxels
# processed 61.875% of voxels
# processed 62.083333333333336% of voxels
# processed 62.291666666666664% of voxels
# processed 62.5% of voxels
# processed 62.708333333333336% of voxels
# processed 62.916666666666664% of voxels
# processed 63.125% of voxels
# processed 63.33333333333333% of voxels
# processed 63.541666666666664% of voxels
# processed 63.74999999999999% of voxels
# processed 63.95833333333333% of voxels
# processed 64.16666666666667% of voxels
# processed 64.375% of voxels
# processed 64.58333333333334% of voxels
# processed 64.79166666666667% of voxels
# processed 65.0% of voxels
# processed 65.20833333333333% of voxels
# processed 65.41666666666667% of voxels
# processed 65.625% of voxels
# processed 65.83333333333333% of voxels
# processed 66.04166666666667% of voxels
# processed 66.25% of voxels
# processed 66.45833333333333% of voxels
# processed 66.66666666666666% of voxels
# processed 66.875% of voxels
# processed 67.08333333333333% of voxels
# processed 67.29166666666667% of voxels
# processed 67.5% of voxels
# processed 67.70833333333334% of voxels
# processed 67.91666666666667% of voxels
# processed 68.125% of voxels
# processed 68.33333333333333% of voxels
# processed 68.54166666666667% of voxels
# processed 68.75% of voxels
# processed 68.95833333333333% of voxels
# processed 69.16666666666667% of voxels
# processed 69.375% of voxels
# processed 69.58333333333333% of voxels
# processed 69.79166666666666% of voxels
# processed 70.0% of voxels
# processed 70.20833333333333% of voxels
# processed 70.41666666666667% of voxels
# processed 70.625% of voxels
# processed 70.83333333333334% of voxels
# processed 71.04166666666667% of voxels
# processed 71.25% of voxels
# processed 71.45833333333333% of voxels
# processed 71.66666666666667% of voxels
# processed 71.875% of voxels
# processed 72.08333333333333% of voxels
# processed 72.29166666666667% of voxels
# processed 72.5% of voxels
# processed 72.70833333333333% of voxels
# processed 72.91666666666666% of voxels
# processed 73.125% of voxels
# processed 73.33333333333333% of voxels
# processed 73.54166666666667% of voxels
# processed 73.75% of voxels
# processed 73.95833333333334% of voxels
# processed 74.16666666666667% of voxels
# processed 74.375% of voxels
# processed 74.58333333333333% of voxels
# processed 74.79166666666667% of voxels
# processed 75.0% of voxels
# processed 75.20833333333333% of voxels
# processed 75.41666666666667% of voxels
# processed 75.625% of voxels
# processed 75.83333333333333% of voxels
# processed 76.04166666666666% of voxels
# processed 76.25% of voxels
# processed 76.45833333333333% of voxels
# processed 76.66666666666667% of voxels
# processed 76.875% of voxels
# processed 77.08333333333334% of voxels
# processed 77.29166666666667% of voxels
# processed 77.5% of voxels
# processed 77.70833333333333% of voxels
# processed 77.91666666666667% of voxels
# processed 78.125% of voxels
# processed 78.33333333333333% of voxels
# processed 78.54166666666667% of voxels
# processed 78.75% of voxels
# processed 78.95833333333333% of voxels
# processed 79.16666666666666% of voxels
# processed 79.375% of voxels
# processed 79.58333333333333% of voxels
# processed 79.79166666666667% of voxels
# processed 80.0% of voxels
# processed 80.20833333333334% of voxels
# processed 80.41666666666667% of voxels
# processed 80.625% of voxels
# processed 80.83333333333333% of voxels
# processed 81.04166666666667% of voxels
# processed 81.25% of voxels
# processed 81.45833333333333% of voxels
# processed 81.66666666666667% of voxels
# processed 81.875% of voxels
# processed 82.08333333333333% of voxels
# processed 82.29166666666666% of voxels
# processed 82.5% of voxels
# processed 82.70833333333333% of voxels
# processed 82.91666666666667% of voxels
# processed 83.125% of voxels
# processed 83.33333333333334% of voxels
# processed 83.54166666666667% of voxels
# processed 83.75% of voxels
# processed 83.95833333333333% of voxels
# processed 84.16666666666667% of voxels
# processed 84.375% of voxels
# processed 84.58333333333333% of voxels
# processed 84.79166666666667% of voxels
# processed 85.0% of voxels
# processed 85.20833333333333% of voxels
# processed 85.41666666666666% of voxels
# processed 85.625% of voxels
# processed 85.83333333333333% of voxels
# processed 86.04166666666667% of voxels
# processed 86.25% of voxels
# processed 86.45833333333334% of voxels
# processed 86.66666666666667% of voxels
# processed 86.875% of voxels
# processed 87.08333333333333% of voxels
# processed 87.29166666666667% of voxels
# processed 87.5% of voxels
# processed 87.70833333333333% of voxels
# processed 87.91666666666667% of voxels
# processed 88.125% of voxels
# processed 88.33333333333333% of voxels
# processed 88.54166666666666% of voxels
# processed 88.75% of voxels
# processed 88.95833333333333% of voxels
# processed 89.16666666666667% of voxels
# processed 89.375% of voxels
# processed 89.58333333333334% of voxels
# processed 89.79166666666667% of voxels
# processed 90.0% of voxels
# processed 90.20833333333333% of voxels
# processed 90.41666666666667% of voxels
# processed 90.625% of voxels
# processed 90.83333333333333% of voxels
# processed 91.04166666666667% of voxels
# processed 91.25% of voxels
# processed 91.45833333333333% of voxels
# processed 91.66666666666666% of voxels
# processed 91.875% of voxels
# processed 92.08333333333333% of voxels
# processed 92.29166666666667% of voxels
# processed 92.5% of voxels
# processed 92.70833333333334% of voxels
# processed 92.91666666666667% of voxels
# processed 93.125% of voxels
# processed 93.33333333333333% of voxels
# processed 93.54166666666667% of voxels
# processed 93.75% of voxels
# processed 93.95833333333333% of voxels
# processed 94.16666666666667% of voxels
# processed 94.375% of voxels
# processed 94.58333333333333% of voxels
# processed 94.79166666666666% of voxels
# processed 95.0% of voxels
# processed 95.20833333333333% of voxels
# processed 95.41666666666667% of voxels
# processed 95.625% of voxels
# processed 95.83333333333334% of voxels
# processed 96.04166666666667% of voxels
# processed 96.25% of voxels
# processed 96.45833333333333% of voxels
# processed 96.66666666666667% of voxels
# processed 96.875% of voxels
# processed 97.08333333333333% of voxels
# processed 97.29166666666667% of voxels
# processed 97.5% of voxels
# processed 97.70833333333333% of voxels
# processed 97.91666666666666% of voxels
# processed 98.125% of voxels
# processed 98.33333333333333% of voxels
# processed 98.54166666666667% of voxels
# processed 98.75% of voxels
# processed 98.95833333333334% of voxels
# processed 99.16666666666667% of voxels
# processed 99.375% of voxels
# processed 99.58333333333333% of voxels
# processed 99.79166666666667% of voxels
# processed 100.0% of voxels
# 480 154 38
